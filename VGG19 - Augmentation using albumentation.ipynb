# %% [markdown]
# <a href="https://colab.research.google.com/github/noprisigit/DenseNet121/blob/main/VGG19%20-%20Augmentation%20using%20albumentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import itertools
from collections import Counter
import pandas as pd

from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
# Mount Google Drive
drive.mount('/content/drive')

# !unzip '/content/drive/MyDrive/dataset-swedesh-score.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAES2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAEU1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFQ2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS07_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAFS08_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGP2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAGQ4_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHP2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHQ2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHR3_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHS3_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAHT5_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJA1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug20.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug21.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug22.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug23.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug24.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug25.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug26.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug27.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug28.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug29.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug30.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug31.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug32.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug33.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug34.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug35.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug36.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug37.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug38.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug39.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 3/AAJI3_aug19.jpg
# ...
#   inflating: dataset-swedesh-score/train_base/CIN 3/C57Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C57Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C57Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C59Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C59Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C61Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C61Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C68Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C68Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C6Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C6Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C71Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C71Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C72Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C76Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C76Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C81Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C81Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C86Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C93Aceto (1).jpg
#    creating: dataset-swedesh-score/train_base/Normal/
#   inflating: dataset-swedesh-score/train_base/Normal/AADE1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AADE3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AADP02.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AADP03.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAEG1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFU1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFU2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFU3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFX3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGB5.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGB8.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGC2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGD3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIL3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIQ2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIQ3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIR2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIS1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C100Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C100Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C100Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C13Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C13Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C13Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C1Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C1Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C23Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C23Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C23Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C28Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C28Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C28Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C32Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C32Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C32Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C36Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C37Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C39Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C47Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C54Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C54Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C60Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C60Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C60Aceto (5).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C77Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C85Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C85Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C94Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C95Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C95Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C96Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C99Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C99Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C9Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C9Aceto (2).jpg
#    creating: dataset-swedesh-score/val/
#    creating: dataset-swedesh-score/val/CIN 1/
#   inflating: dataset-swedesh-score/val/CIN 1/AAAJ2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAP4.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAT3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAV0.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAW3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAY04.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AADG2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AADK05.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEA1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAED1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEF04.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEF05.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEM2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFE3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFG1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFI3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFL1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFP1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFY3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAGG2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAGI0.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAGZ3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAHE.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAIC1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAII2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAIN4.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAIX1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAJE1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAJF3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAJG3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C11Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C22Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C27Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C27Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C2Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C2Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C30Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C31Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C31Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C31Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C40Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C43Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C4Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C4Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C51Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C51Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C58Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C58Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C5Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C62Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C64Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C70Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C70Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C75Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C75Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C75Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C80Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C80Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C84Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C84Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C88Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C89Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C89Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C97Aceto (2).jpg
#    creating: dataset-swedesh-score/val/CIN 2/
#   inflating: dataset-swedesh-score/val/CIN 2/AAAZ4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADF4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADQ10.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADR04.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADR09.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAGY4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAHN2.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAIF4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAIW1.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C12Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C12Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C12Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C14Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C15Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C15Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C15Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C19Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C29Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C34Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C34Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C50Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C53Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C63Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C67Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C69Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C73Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C7Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C87Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C8Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C92Aceto (3).jpg
#    creating: dataset-swedesh-score/val/CIN 3/
#   inflating: dataset-swedesh-score/val/CIN 3/AAAB3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAAE3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAAH11.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABG1.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABI3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABL0.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABL1.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABM1.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABR08.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABS05.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABT3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABX15.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACA2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACD5.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACM2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACO2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAFQ3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAFQ5.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAFS04.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAGP4.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHO2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHT3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHU3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHU4.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHU6.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAJJ2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAJK3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C16Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C16Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C33Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C33Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C44Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C44Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C48Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C59Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C68Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C6Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C6Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C6Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C71Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C76Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C86Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C93Aceto (2).jpg
#    creating: dataset-swedesh-score/val/Normal/
#   inflating: dataset-swedesh-score/val/Normal/AADE0.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAFC3.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAFK2.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAFW3.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAGB7.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAGF1.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAHC09.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAIP2.jpg
#   inflating: dataset-swedesh-score/val/Normal/C13Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C13Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/Normal/C1Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/Normal/C28Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C36Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C37Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C38Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C38Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C39Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C47Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C60Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C60Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/Normal/C77Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C85Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C94Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C96Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C96Aceto (2).jpg

# %%
# Dataset Path
data_dir = '/content/dataset-swedesh-score'
train_dir = os.path.join(data_dir, 'train')
val_dir = os.path.join(data_dir, 'val')

# Count Dataset
def count_dataset(directory):
  class_counts = {}
  total_count = 0

  for class_name in os.listdir(directory):
    class_path = os.path.join(directory, class_name)
    if (os.path.isdir(class_path)):
      num_images = len(os.listdir(class_path))
      class_counts[class_name] = num_images
      total_count += num_images

  return class_counts, total_count

total_images, class_distribution = count_dataset(train_dir)
print(f'Total Images Training: {total_images}')
print('Class Distribution Training:', class_distribution)

total_images, class_distribution = count_dataset(val_dir)
print(f'Total Images Validation: {total_images}')
print('Class Distribution Validation:', class_distribution)
# Out:
# Total Images Training: {'CIN 2': 2760, 'CIN 1': 6280, 'CIN 3': 3800, 'Normal': 2200}
# Class Distribution Training: 15040
# Total Images Validation: {'CIN 2': 30, 'CIN 1': 68, 'CIN 3': 43, 'Normal': 25}
# Class Distribution Validation: 166

# %%
def image_CALHE(image):
    # Ensure the image is in the correct data type before CLAHE
    image = image.astype(np.uint8)  # Convert to 8-bit if it's not already

    # Thresholding
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 155, 255, cv2.THRESH_BINARY)

    # CLAHE (Contrast Limited Adaptive Histogram Equalization)
    clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(8, 8))
    # Apply CLAHE to the original grayscale image
    clahe_img = clahe.apply(gray)

    # Clip and convert to uint8 after CLAHE application
    clahe_img = np.clip(clahe_img + 30, 0, 255).astype(np.uint8)

    cl1 = cv2.cvtColor(clahe_img, cv2.COLOR_GRAY2BGR)

    # Convert the output to float32 to avoid type mismatch during rescaling
    cl1 = cl1.astype(np.float32)

    return cl1

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# Augmentasi data untuk train set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    # zoom_range=0.2,
    # rotation_range=70,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # horizontal_flip=True,
    fill_mode='nearest',
    preprocessing_function=image_CALHE
)
# train_datagen = ImageDataGenerator(rescale=1./255)

# Hanya rescale untuk validation dan test set
val_test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=image_CALHE
)

# Data generator untuk train, validation, dan test set
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',

    shuffle=False,
)
# Out:
# Found 15040 images belonging to 4 classes.
# Found 166 images belonging to 4 classes.

# %%
# Display Sample Images
# def plot_sample_images(generator):
#   class_names = list(generator.class_indices.keys())
#   plt.figure(figsize=(10, 5))

#   for i in range(6):
#     img, label = next(generator)
#     plt.subplot(2, 3, i + 1)
#     plt.imshow(img[0])
#     plt.title(class_names[np.argmax(label[0])])
#     plt.axis('off')

#   plt.show()

# plot_sample_images(train_generator)
gen_dict = train_generator.class_indices
classes = list(gen_dict.keys())
images , labels = next(train_generator)
plt.figure(figsize= (20,20))

for i in range(16):
    plt.subplot(4,4,i+1)
    image = images[i] # / 255
    plt.imshow(image)
    index = np.argmax(labels[i])
    class_name = classes[index]
    plt.title(class_name , color = 'black' , fontsize= 16)
    plt.axis('off')
plt.show();

# %%
# Hitung Class Weighs

class_indices = train_generator.class_indices
print("Class indices:", class_indices)

labels = train_generator.classes  # array of class index per sample
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)
# Out:
# Class indices: {'CIN 1': 0, 'CIN 2': 1, 'CIN 3': 2, 'Normal': 3}
# Class weights: {0: np.float64(0.5987261146496815), 1: np.float64(1.3623188405797102), 2: np.float64(0.9894736842105263), 3: np.float64(1.709090909090909)}

# %%
# Load MobileNetV2 dengan weights 'imagenet' dan tanpa top layer
base_model = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base model
for layer in base_model.layers:
    layer.trainable = False

# Tambahkan custom top layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dense(2048, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.001))(x)

# Bangun model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2048)           │     1,050,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         8,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,083,204 (80.43 MB)
#  Trainable params: 1,058,820 (4.04 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

callbacks = [early_stop]

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    # class_weight=class_weights,
    # callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 114s 211ms/step - accuracy: 0.4129 - loss: 1.5625 - val_accuracy: 0.4458 - val_loss: 1.3257
# Epoch 2/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.4467 - loss: 1.2888 - val_accuracy: 0.4578 - val_loss: 1.2966
# Epoch 3/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.4504 - loss: 1.2670 - val_accuracy: 0.4458 - val_loss: 1.2673
# Epoch 4/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.4669 - loss: 1.2396 - val_accuracy: 0.4639 - val_loss: 1.2569
# Epoch 5/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 142s 203ms/step - accuracy: 0.4720 - loss: 1.2403 - val_accuracy: 0.4759 - val_loss: 1.2583
# Epoch 6/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.4682 - loss: 1.2260 - val_accuracy: 0.4699 - val_loss: 1.2801
# Epoch 7/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.4859 - loss: 1.2087 - val_accuracy: 0.4819 - val_loss: 1.2714
# Epoch 8/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.4857 - loss: 1.2059 - val_accuracy: 0.4759 - val_loss: 1.2429
# Epoch 9/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5009 - loss: 1.1947 - val_accuracy: 0.4819 - val_loss: 1.2512
# Epoch 10/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 141s 203ms/step - accuracy: 0.4977 - loss: 1.1931 - val_accuracy: 0.4940 - val_loss: 1.2458
# Epoch 11/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5048 - loss: 1.1801 - val_accuracy: 0.5000 - val_loss: 1.2446
# Epoch 12/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5057 - loss: 1.1702 - val_accuracy: 0.5000 - val_loss: 1.2445
# Epoch 13/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5172 - loss: 1.1635 - val_accuracy: 0.5000 - val_loss: 1.2725
# Epoch 14/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5121 - loss: 1.1664 - val_accuracy: 0.5120 - val_loss: 1.2529
# Epoch 15/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 203ms/step - accuracy: 0.5242 - loss: 1.1532 - val_accuracy: 0.5060 - val_loss: 1.2470
# Epoch 16/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5198 - loss: 1.1582 - val_accuracy: 0.5120 - val_loss: 1.2645
# Epoch 17/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.
100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 142s 203ms/step - accuracy: 0.6015 - loss: 1.0767 - val_accuracy: 0.4759 - val_loss: 1.3360
# Epoch 79/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6027 - loss: 1.0816 - val_accuracy: 0.5181 - val_loss: 1.3015
# Epoch 80/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5942 - loss: 1.0848 - val_accuracy: 0.4518 - val_loss: 1.3401
# Epoch 81/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5990 - loss: 1.0761 - val_accuracy: 0.4880 - val_loss: 1.3107
# Epoch 82/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6091 - loss: 1.0685 - val_accuracy: 0.5181 - val_loss: 1.3030
# Epoch 83/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6009 - loss: 1.0758 - val_accuracy: 0.5301 - val_loss: 1.2936
# Epoch 84/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6081 - loss: 1.0676 - val_accuracy: 0.4880 - val_loss: 1.3102
# Epoch 85/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6107 - loss: 1.0641 - val_accuracy: 0.5060 - val_loss: 1.3233
# Epoch 86/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5990 - loss: 1.0812 - val_accuracy: 0.4819 - val_loss: 1.3180
# Epoch 87/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6118 - loss: 1.0673 - val_accuracy: 0.5120 - val_loss: 1.3055
# Epoch 88/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6098 - loss: 1.0700 - val_accuracy: 0.5000 - val_loss: 1.3019
# Epoch 89/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6070 - loss: 1.0689 - val_accuracy: 0.5060 - val_loss: 1.3008
# Epoch 90/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6127 - loss: 1.0690 - val_accuracy: 0.5060 - val_loss: 1.3031
# Epoch 91/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6107 - loss: 1.0722 - val_accuracy: 0.4639 - val_loss: 1.3273
# Epoch 92/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6120 - loss: 1.0811 - val_accuracy: 0.5000 - val_loss: 1.3318
# Epoch 93/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6056 - loss: 1.0782 - val_accuracy: 0.4880 - val_loss: 1.3076
# Epoch 94/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.5998 - loss: 1.0861 - val_accuracy: 0.5000 - val_loss: 1.3107
# Epoch 95/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 203ms/step - accuracy: 0.6097 - loss: 1.0724 - val_accuracy: 0.5060 - val_loss: 1.3377
# Epoch 96/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6092 - loss: 1.0605 - val_accuracy: 0.4940 - val_loss: 1.3260
# Epoch 97/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6145 - loss: 1.0624 - val_accuracy: 0.4940 - val_loss: 1.3160
# Epoch 98/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 203ms/step - accuracy: 0.6154 - loss: 1.0673 - val_accuracy: 0.5060 - val_loss: 1.3035
# Epoch 99/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 142s 203ms/step - accuracy: 0.6154 - loss: 1.0738 - val_accuracy: 0.5241 - val_loss: 1.3097
# Epoch 100/100
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.6069 - loss: 1.0781 - val_accuracy: 0.4940 - val_loss: 1.3216

# %%
# Evaluate the model on the test set
train_loss, train_acc = model.evaluate(train_generator)
print(f'Train Accuracy: {train_acc:.4f}')
print(f'Train Loss: {train_loss:.4f}')

val_loss, val_acc = model.evaluate(val_generator)
print(f'Val Accuracy: {val_acc:.4f}')
print(f'Val Loss: {val_loss:.4f}')

# === EVALUASI: NILAI TERBAIK ===
best_epoch = np.argmax(history.history['val_accuracy'])
print(f"🏆 Best Epoch: {best_epoch+1}")
print(f"✅ Best Train Acc: {history.history['accuracy'][best_epoch]:.4f}")
print(f"✅ Best Val Acc: {history.history['val_accuracy'][best_epoch]:.4f}")
print(f"📉 Best Train Loss: {history.history['loss'][best_epoch]:.4f}")
print(f"📉 Best Val Loss: {history.history['val_loss'][best_epoch]:.4f}")

# Predict the test set
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# Classification report
print(classification_report(y_true, y_pred_classes, target_names=['Normal', 'CIN1', 'CIN2', 'CIN3']))

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'CIN1', 'CIN2', 'CIN3'], yticklabels=['Normal', 'CIN1', 'CIN2', 'CIN3'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
colors = ['blue', 'red', 'green', 'yellow']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of class {i} (area = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Multi-Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 95s 201ms/step - accuracy: 0.6940 - loss: 0.9557
# Train Accuracy: 0.6920
# Train Loss: 0.9581
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.5974 - loss: 1.1233
# Val Accuracy: 0.4940
# Val Loss: 1.3216
# 🏆 Best Epoch: 53
# ✅ Best Train Acc: 0.5803
# ✅ Best Val Acc: 0.5542
# 📉 Best Train Loss: 1.0936
# 📉 Best Val Loss: 1.2773
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step
#               precision    recall  f1-score   support
#
#       Normal       0.51      0.79      0.62        68
#         CIN1       0.29      0.23      0.26        30
#         CIN2       0.61      0.40      0.48        43
#         CIN3       0.44      0.16      0.24        25
#
#     accuracy                           0.49       166
#    macro avg       0.46      0.40      0.40       166
# weighted avg       0.49      0.49      0.46       166

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import recall_score, precision_score, f1_score

# Calculate sensitivity (recall), precision, and F1-score
sensitivity = recall_score(y_true, y_pred_classes, average=None)
precision = precision_score(y_true, y_pred_classes, average=None)
f1 = f1_score(y_true, y_pred_classes, average=None)

# Calculate specificity
specificity = []
for i in range(3):
    tn = np.sum((y_true != i) & (y_pred_classes != i))
    fp = np.sum((y_true != i) & (y_pred_classes == i))
    specificity.append(tn / (tn + fp))

print(f'Sensitivity: {sensitivity}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'Specificity: {specificity}')
# Out:
# Sensitivity: [0.79411765 0.23333333 0.39534884 0.16      ]
# Precision: [0.51428571 0.29166667 0.60714286 0.44444444]
# F1-Score: [0.62427746 0.25925926 0.47887324 0.23529412]
# Specificity: [np.float64(0.47959183673469385), np.float64(0.875), np.float64(0.9105691056910569)]

# %%
# import numpy as np
# import tensorflow as tf
# import matplotlib.pyplot as plt
# import cv2

# # Fungsi untuk membuat Grad-CAM
# def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
#     grad_model = tf.keras.models.Model(
#         [model.inputs],
#         [model.get_layer(last_conv_layer_name).output, model.output]
#     )

#     with tf.GradientTape() as tape:
#         conv_outputs, predictions = grad_model(img_array)
#         if pred_index is None:
#             pred_index = tf.argmax(predictions[0])
#         class_channel = predictions[:, pred_index]

#     grads = tape.gradient(class_channel, conv_outputs)
#     pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     conv_outputs = conv_outputs[0]
#     heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
#     heatmap = tf.squeeze(heatmap)
#     heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
#     return heatmap.numpy()

# # Fungsi untuk tampilkan Grad-CAM
# def show_gradcam(image_path, model, last_conv_layer_name='Conv_1'):
#     img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
#     img_array = tf.keras.preprocessing.image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

#     heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

#     img = cv2.imread(image_path)
#     img = cv2.resize(img, (224, 224))
#     heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
#     heatmap = np.uint8(255 * heatmap)
#     heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
#     superimposed_img = heatmap_color * 0.4 + img

#     plt.figure(figsize=(8, 8))
#     plt.imshow(cv2.cvtColor(superimposed_img.astype("uint8"), cv2.COLOR_BGR2RGB))
#     plt.axis('off')
#     plt.title('Grad-CAM')
#     plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2
# from tensorflow.keras.preprocessing import image

# def compute_cam(model, img_path, target_size=(224, 224), class_idx=None):
#     # Ambil image dan preprocess
#     img = image.load_img(img_path, target_size=target_size)
#     img_array = image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

#     # Buat model tanpa softmax
#     cam_model = tf.keras.Model(inputs=model.input, outputs=[model.get_layer("Conv_1").output, model.output])
#     conv_outputs, predictions = cam_model.predict(img_array)

#     if class_idx is None:
#         class_idx = np.argmax(predictions[0])

#     # Ambil bobot dari FC layer terakhir
#     final_dense = model.get_layer(index=-1)  # Dense layer terakhir
#     weights = final_dense.get_weights()[0]  # shape: (num_filters, num_classes)

#     # Dot product antara feature map dan bobot class tertentu
#     cam = np.dot(conv_outputs[0], weights[:, class_idx])

#     # Normalisasi
#     cam = cv2.resize(cam, target_size)
#     cam = np.maximum(cam, 0)
#     cam = cam / cam.max()

#     # Overlay CAM
#     heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, target_size)
#     overlay = heatmap * 0.4 + img

#     # Tampilkan
#     plt.figure(figsize=(6,6))
#     plt.imshow(cv2.cvtColor(overlay.astype("uint8"), cv2.COLOR_BGR2RGB))
#     plt.title(f'CAM untuk kelas {class_idx}')
#     plt.axis('off')
#     plt.show()

# %%
# x_batch, y_batch = next(train_generator)  # ambil batch pertama

# # Simpan 1 gambar per kelas
# class_indices = np.argmax(y_batch, axis=1)  # ubah one-hot ke label

# saved_images = {}
# for idx, label in enumerate(class_indices):
#     if label not in saved_images:
#         img = x_batch[idx]
#         img_path = f'class_{label}_sample.jpg'
#         tf.keras.preprocessing.image.save_img(img_path, img)
#         saved_images[label] = img_path

#     if len(saved_images) == 3:  # kalau sudah semua kelas ditemukan
#         break

# for label, img_path in saved_images.items():
#     print(f"\nGrad-CAM dan CAM untuk Kelas: {label}")

#     print("Grad-CAM:")
#     show_gradcam(img_path, model)

#     # print("CAM:")
#     # compute_cam(model, img_path, class_idx=label)

# %%
# x_batch, y_batch = next(val_generator)  # ambil batch pertama

# # Simpan 1 gambar per kelas
# class_indices = np.argmax(y_batch, axis=1)  # ubah one-hot ke label

# saved_images = {}
# for idx, label in enumerate(class_indices):
#     if label not in saved_images:
#         img = x_batch[idx]
#         img_path = f'class_{label}_sample.jpg'
#         tf.keras.preprocessing.image.save_img(img_path, img)
#         saved_images[label] = img_path

#     if len(saved_images) == 3:  # kalau sudah semua kelas ditemukan
#         break

# for label, img_path in saved_images.items():
#     print(f"\nGrad-CAM dan CAM untuk Kelas: {label}")

#     print("Grad-CAM:")
#     show_gradcam(img_path, model)

#     # print("CAM:")
#     # compute_cam(model, img_path, class_idx=label)
